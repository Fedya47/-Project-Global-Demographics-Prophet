# %% [markdown]
# Проверка

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('Data.csv', skipfooter=5, engine='python')
df
# Out:
#    Country Name Country Code  \
# 0         World          WLD
# 1         World          WLD
# 2         World          WLD
# 3         World          WLD
# 4         World          WLD
# 5         World          WLD
# 6         World          WLD
# 7         World          WLD
# 8         World          WLD
# 9         World          WLD
# 10        World          WLD
# 11        World          WLD
# 12        World          WLD
# 13        World          WLD
# 14        World          WLD
# 15        World          WLD
# 16        World          WLD
# 17        World          WLD
# 18        World          WLD
#
#                                           Series Name        Series Code  \
# 0                                   Population, total        SP.POP.TOTL
# 1          Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 2                Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 3                Death rate, crude (per 1,000 people)     SP.DYN.CDRT.IN
# 4            Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# 5             Life expectancy at birth, total (years)     SP.DYN.LE00.IN
# 6      Mortality rate, infant (per 1,000 live births)     SP.DYN.IMRT.IN
# 7                        Population growth (annual %)        SP.POP.GROW
# 8        Population ages 0-14 (% of total population)  SP.POP.0014.TO.ZS
# 9       Population ages 15-64 (% of total population)  SP.POP.1564.TO.ZS
# 10  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 11           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 12      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 13                                 Labor force, total     SL.TLF.TOTL.IN
# 14  People using at least basic drinking water ser...     SH.H2O.BASW.ZS
# 15  Contraceptive prevalence, any method (% of mar...     SP.DYN.CONU.ZS
# 16  Prevalence of HIV, total (% of population ages...     SH.DYN.AIDS.ZS
# 17  Current health expenditure per capita, PPP (cu...  SH.XPD.CHEX.PP.CD
# 18  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
#
#        2024 [YR2024]      2023 [YR2023]     2022 [YR2022]      2021 [YR2021]  \
# 0         8142056446         8064976601        7990399768         7920861888
# 1    49.720940485403   49.7090938984064  49.6968409791225   49.6879141492495
# 2                 ..   16.3327648376098  16.5567442314174   16.8437566819204
# 3                 ..   7.57875299565788  7.70740462027798   8.71260338990372
# 4                 ..   2.19582603257397  2.21514971296506   2.24573573357195
# 5                 ..   73.3297162833404  72.9690157226638   71.2154841745704
# 6                 ..               27.1                28               28.1
# 7   0.95119724803841  0.929001820256677  0.87407679206444  0.834019678889311
# 8   24.7262356323755   25.0437186765879  25.3453926748796   25.6066173001413
# 9   65.0730251006191   64.9749802281763  64.9156756903772    64.866574625801
# 10  10.2007392670054   9.98130109523578  9.73893163474312   9.52680807405771
# 11  57.7006387971638   57.2603934495146   56.815715402616   56.3752739801048
# 12  24247.9375140792   23048.6731395489  21795.5422800663   19742.3647128621
# 13        3696440187         3652582378        3600564783         3560995662
# 14                ..                 ..  91.0845798511766   90.6703177799413
# 15                ..                 ..                ..                 ..
# 16               0.7                0.7               0.7                0.7
# 17                ..                 ..  1724.76457249082   1644.43887483522
# 18                ..   3.51483161383978  3.84722961564427   4.23262732662743
#
#         2020 [YR2020]     2019 [YR2019]  ...     1969 [YR1969]  \
# 0          7855075060        7778303912  ...        3604815552
# 1    49.6726759319373  49.6644661997728  ...  50.0153909775721
# 2    17.1491582639446  17.8031443074795  ...  32.8215760699129
# 3    8.01146403762778    7.468179369352  ...  12.2260828851215
# 4    2.27638060434278  2.35323784811332  ...  4.88003252839929
# 5    72.1822239463873  72.8689103086688  ...  57.6800785564019
# 6                28.5              28.9  ...                ..
# 7   0.982151910510213  1.04436974995153  ...  2.07734447832581
# 8    25.8315084265701  26.0365830261538  ...  37.8410091649078
# 9     64.837637448982  64.8587194013205  ...  56.9197035238378
# 10   9.33085412444791  9.10469757252571  ...  5.23928731125443
# 11   55.9623738261611  55.5315178075519  ...  36.3478850692389
# 12   17808.0573966815  18037.3592033385  ...                ..
# 13         3480412639        3511583639  ...                ..
# 14   90.2577487261197  89.8742712487533  ...                ..
# 15                 ..                ..  ...                ..
# 16                0.8               0.8  ...                ..
# 17   1545.31462752416   1430.2746701269  ...                ..
# 18   4.34224486351013  4.15776014328003  ...                ..
#
#        1968 [YR1968]     1967 [YR1967]     1966 [YR1966]     1965 [YR1965]  \
# 0         3530703561        3459015356        3389087189        3318997522
# 1   50.0242058938275  50.0306621136238  50.0374012265362  50.0462145959938
# 2     33.31704877056  33.1903954191732  33.4763322767604  34.5165843533564
# 3   12.3868564238268  12.6248516968463  12.9112368139789  13.3335515550382
# 4   4.97825772929304  4.86580781697261  4.96824850941136  5.08093194731238
# 5   57.3352975180805  56.9037526493978  56.4490075635883   55.926447643924
# 6                 ..                ..                ..                ..
# 7   2.05131907724086  2.04233500264312  2.08978332249744   2.0622264110062
# 8   37.9077210047276  37.9808877864873  38.0433528061241  38.0303884227707
# 9   56.8922994598399   56.860973432274  56.8394713857178  56.8918666890537
# 10  5.19997953543241  5.15813878123875  5.11717580815803  5.07774488817559
# 11  36.1511696364289  35.9458745314618  35.7366419321331  35.5400946352421
# 12                ..                ..                ..                ..
# 13                ..                ..                ..                ..
# 14                ..                ..                ..                ..
# 15                ..                ..                ..                ..
# 16                ..                ..                ..                ..
# 17                ..                ..                ..                ..
# 18                ..                ..                ..                ..
#
#        1964 [YR1964]     1963 [YR1963]     1962 [YR1962]     1961 [YR1961]  \
# 0         3251253200        3184063049        3117372187        3062768116
# 1    50.057772597255  50.0723542498722  50.0874204611387   50.097862877634
# 2   35.1867341754549  36.3474563845187  35.1632445830402  31.2341888501891
# 3   13.5207577307396  13.4290583745492  13.5844076991565  14.5595576375874
# 4   5.13081514120538  5.31430470898607  5.02406253709377  4.56475472574651
# 5   56.0966979719764  55.6522285444853  55.2860734026534  52.7972301278289
# 6                 ..                ..                ..                ..
# 7   2.08824524093807  2.11676704326362  1.76712790546867  1.35615538573255
# 8   37.9664516558849   37.787951398339   37.563933284623  37.4692001388481
# 9   56.9905441911528    57.18766795986  57.4255483623954  57.5412121009554
# 10  5.04300415296226  5.02438064180108  5.01051835298167  4.98958776019639
# 11   35.324654158142  34.9418512614261     34.5665624881  34.1368087915671
# 12                ..                ..                ..                ..
# 13                ..                ..                ..                ..
# 14                ..                ..                ..                ..
# 15                ..                ..                ..                ..
# 16                ..                ..                ..                ..
# 17                ..                ..                ..                ..
# 18                ..                ..                ..                ..
#
#        1960 [YR1960]
# 0         3021512598
# 1   50.1014286800275
# 2   31.9992347613353
# 3   17.2114690145631
# 4   4.68612947945316
# 5   50.9418860745353
# 6                 ..
# 7                 ..
# 8    37.398947202015
# 9   57.6310744053493
# 10  4.96997839263569
# 11  33.6513215497821
# 12                ..
# 13                ..
# 14                ..
# 15                ..
# 16                ..
# 17                ..
# 18                ..
#
# [19 rows x 69 columns]

# %%
year_columns = [col for col in df.columns if '[YR' in col]
rename_map = {
    col: re.sub(r' \[YR\d{4}\]', '', col)
    # Значение: удаляем паттерн " [YRXXXX]"
    for col in year_columns
}
df_renamed = df.rename(columns=rename_map)

# %%
df = df.rename(columns=rename_map)

# %%
# Превращаем таблицу в длинный формат
df_long = df.melt(
    id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'], # То, что НЕ меняется
    var_name='Year',  # Как назвать колонку, куда упадут заголовки (бывшие 2020, 2021...)
    value_name='Value' # Как назвать колонку, куда упадут цифры
)

# Превращаем год в число (так как имена колонок были строками)
df_long['Year'] = df_long['Year'].astype(int)
df_long['Value'] = pd.to_numeric(df_long['Value'], errors='coerce')

print(df_long.head())
# Out:
#   Country Name Country Code                                 Series Name  \
# 0        World          WLD                           Population, total
# 1        World          WLD  Population, female (% of total population)
# 2        World          WLD        Birth rate, crude (per 1,000 people)
# 3        World          WLD        Death rate, crude (per 1,000 people)
# 4        World          WLD    Fertility rate, total (births per woman)
#
#          Series Code  Year         Value
# 0        SP.POP.TOTL  2024  8.142056e+09
# 1  SP.POP.TOTL.FE.ZS  2024  4.972094e+01
# 2     SP.DYN.CBRT.IN  2024           NaN
# 3     SP.DYN.CDRT.IN  2024           NaN
# 4     SP.DYN.TFRT.IN  2024           NaN

# %%
df_long.head(10)
# Out:
#   Country Name Country Code                                     Series Name  \
# 0        World          WLD                               Population, total
# 1        World          WLD      Population, female (% of total population)
# 2        World          WLD            Birth rate, crude (per 1,000 people)
# 3        World          WLD            Death rate, crude (per 1,000 people)
# 4        World          WLD        Fertility rate, total (births per woman)
# 5        World          WLD         Life expectancy at birth, total (years)
# 6        World          WLD  Mortality rate, infant (per 1,000 live births)
# 7        World          WLD                    Population growth (annual %)
# 8        World          WLD    Population ages 0-14 (% of total population)
# 9        World          WLD   Population ages 15-64 (% of total population)
#
#          Series Code  Year         Value
# 0        SP.POP.TOTL  2024  8.142056e+09
# 1  SP.POP.TOTL.FE.ZS  2024  4.972094e+01
# 2     SP.DYN.CBRT.IN  2024           NaN
# 3     SP.DYN.CDRT.IN  2024           NaN
# 4     SP.DYN.TFRT.IN  2024           NaN
# 5     SP.DYN.LE00.IN  2024           NaN
# 6     SP.DYN.IMRT.IN  2024           NaN
# 7        SP.POP.GROW  2024  9.511972e-01
# 8  SP.POP.0014.TO.ZS  2024  2.472624e+01
# 9  SP.POP.1564.TO.ZS  2024  6.507303e+01

# %%
df_long['Country Name'].nunique()
# Out:
# 1

# %%
muss = df_long['Value'].isna().mean() * 100
muss
# Out:
# np.float64(25.34412955465587)

# %%
missing = df_long.isna().sum()

# %%
missing
# Out:
# Country Name      0
# Country Code      0
# Series Name       0
# Series Code       0
# Year              0
# Value           313
# dtype: int64

# %%
df_long.shape
# Out:
# (1235, 6)

# %%
#Missing_Count это количество пропущенных значений
#Missing_Pct это процент пропущенных значений
missing_stats = df_long.groupby('Series Name')['Value'].agg(
    Missing_Count = lambda x: x.isna().sum(),
    Missing_Pct = lambda x: x.isna().mean() * 100
).sort_values(by='Missing_Pct', ascending=False)
print(missing_stats)
# Out:
#                                                     Missing_Count  Missing_Pct
# Series Name
# Contraceptive prevalence, any method (% of marr...             63    96.923077
# Current health expenditure per capita, PPP (cur...             42    64.615385
# People using at least basic drinking water serv...             42    64.615385
# Government expenditure on education, total (% o...             40    61.538462
# Mortality rate, infant (per 1,000 live births)                 31    47.692308
# Labor force, total                                             30    46.153846
# GDP per capita, PPP (current international $)                  30    46.153846
# Prevalence of HIV, total (% of population ages ...             30    46.153846
# Birth rate, crude (per 1,000 people)                            1     1.538462
# Death rate, crude (per 1,000 people)                            1     1.538462
# Fertility rate, total (births per woman)                        1     1.538462
# Life expectancy at birth, total (years)                         1     1.538462
# Population growth (annual %)                                    1     1.538462
# Population ages 15-64 (% of total population)                   0     0.000000
# Population ages 0-14 (% of total population)                    0     0.000000
# Population ages 65 and above (% of total popula...              0     0.000000
# Population, female (% of total population)                      0     0.000000
# Population, total                                               0     0.000000
# Urban population (% of total population)                        0     0.000000

# %% [markdown]
# 1. Группа "Идеальные" (1.5% пропусков)
# Кто это: Birth rate, Death rate, Life expectancy, Population growth.
#
# Почему 1.5%? Это ровно 1 год из 65 (1/65 ≈ 1.5%).
#
# Какой год пропущен? Это 2024 год.
#
# Вывод: Это супер-качественные данные. Они есть с 1960 по 2023 год. Пропуск в 2024 году абсолютно нормален — год еще не закончился или данные еще обрабатываются.
#
# 2. Группа "Новая эпоха" (~46% пропусков)
# Кто это: GDP per capita (ВВП), Labor force (Рабочая сила), HIV (ВИЧ).
#
# Почему 46%? Это ровно 30 лет (1960–1989).
#
# История: Данные по ВВП (по паритету покупательной способности) и ВИЧ начали системно собирать только с 1990 года.
#
# Вывод: Если ты будешь строить график ВВП, он начнется с 1990 года. Не пытайся заполнить 1960–1989 годы — этих данных просто не существует в таком формате.
#
# 3. Группа "Эпизодические" (97% пропусков)
# Кто это: Contraceptive prevalence.
#
# Почему 97%? Данные есть всего за 2 года (обычно это годы больших переписей или опросов, например 2000 и 2010).
#
# Вывод: Этот показатель нельзя использовать для временных рядов (line chart). Его можно использовать только как "точечное" сравнение. Для проекта с графиками по годам этот столбец лучше удалить.

# %%
# Фильтруем данные, оставляя только с 1990 года
# Так как данных до 1990 года очень много пропущено
df_recent = df_long[df_long['Year'] >= 1990]

# %%
missing_stats = df_recent.groupby('Series Name')['Value'].agg(
    Missing_Count = lambda x: x.isna().sum(),
    Missing_Pct = lambda x: x.isna().mean() * 100
).sort_values(by='Missing_Pct', ascending=False)
print(missing_stats)
# Out:
#                                                     Missing_Count  Missing_Pct
# Series Name
# Contraceptive prevalence, any method (% of marr...             33    94.285714
# Current health expenditure per capita, PPP (cur...             12    34.285714
# People using at least basic drinking water serv...             12    34.285714
# Government expenditure on education, total (% o...             10    28.571429
# Birth rate, crude (per 1,000 people)                            1     2.857143
# Fertility rate, total (births per woman)                        1     2.857143
# Death rate, crude (per 1,000 people)                            1     2.857143
# Mortality rate, infant (per 1,000 live births)                  1     2.857143
# Life expectancy at birth, total (years)                         1     2.857143
# GDP per capita, PPP (current international $)                   0     0.000000
# Labor force, total                                              0     0.000000
# Population ages 0-14 (% of total population)                    0     0.000000
# Population ages 15-64 (% of total population)                   0     0.000000
# Population ages 65 and above (% of total popula...              0     0.000000
# Population growth (annual %)                                    0     0.000000
# Population, female (% of total population)                      0     0.000000
# Population, total                                               0     0.000000
# Prevalence of HIV, total (% of population ages ...              0     0.000000
# Urban population (% of total population)                        0     0.000000

# %%
df_final = df_recent[df_recent['Series Name'] != 'Contraceptive prevalence, any method (% of married women ages 15-49)'].copy()

# %%
df_final['Value'] = df_final.groupby('Series Name')['Value'].ffill()

# %%
missing_stats_final = df_final.groupby('Series Name')['Value'].agg(
    Missing_Count = lambda x: x.isna().sum(),
    Missing_Pct = lambda x: x.isna().mean() * 100
).sort_values(by='Missing_Pct', ascending=False)

print("✅ Статистика пропусков после очистки:")
print(missing_stats_final)
# Out:
# ✅ Статистика пропусков после очистки:
#                                                     Missing_Count  Missing_Pct
# Series Name
# Current health expenditure per capita, PPP (cur...              2     5.714286
# People using at least basic drinking water serv...              2     5.714286
# Birth rate, crude (per 1,000 people)                            1     2.857143
# Death rate, crude (per 1,000 people)                            1     2.857143
# Government expenditure on education, total (% o...              1     2.857143
# Fertility rate, total (births per woman)                        1     2.857143
# Mortality rate, infant (per 1,000 live births)                  1     2.857143
# Life expectancy at birth, total (years)                         1     2.857143
# GDP per capita, PPP (current international $)                   0     0.000000
# Labor force, total                                              0     0.000000
# Population ages 0-14 (% of total population)                    0     0.000000
# Population ages 15-64 (% of total population)                   0     0.000000
# Population ages 65 and above (% of total popula...              0     0.000000
# Population growth (annual %)                                    0     0.000000
# Population, female (% of total population)                      0     0.000000
# Population, total                                               0     0.000000
# Prevalence of HIV, total (% of population ages ...              0     0.000000
# Urban population (% of total population)                        0     0.000000

# %%
df_final['Value'] = df_final.groupby('Series Name')['Value'].bfill()

# %%
missing_stats_final = df_final.groupby('Series Name')['Value'].agg(
    Missing_Count = lambda x: x.isna().sum(),
    Missing_Pct = lambda x: x.isna().mean() * 100
).sort_values(by='Missing_Pct', ascending=False)

print("Статистика пропусков после очистки:")
print(missing_stats_final)
# Out:
# Статистика пропусков после очистки:
#                                                     Missing_Count  Missing_Pct
# Series Name
# Birth rate, crude (per 1,000 people)                            0          0.0
# Current health expenditure per capita, PPP (cur...              0          0.0
# Death rate, crude (per 1,000 people)                            0          0.0
# Fertility rate, total (births per woman)                        0          0.0
# GDP per capita, PPP (current international $)                   0          0.0
# Government expenditure on education, total (% o...              0          0.0
# Labor force, total                                              0          0.0
# Life expectancy at birth, total (years)                         0          0.0
# Mortality rate, infant (per 1,000 live births)                  0          0.0
# People using at least basic drinking water serv...              0          0.0
# Population ages 0-14 (% of total population)                    0          0.0
# Population ages 15-64 (% of total population)                   0          0.0
# Population ages 65 and above (% of total popula...              0          0.0
# Population growth (annual %)                                    0          0.0
# Population, female (% of total population)                      0          0.0
# Population, total                                               0          0.0
# Prevalence of HIV, total (% of population ages ...              0          0.0
# Urban population (% of total population)                        0          0.0

# %% [markdown]
# #Дальше идем делать графики

# %%
plt.figure(figsize=(12, 6))

# %%
pop_data = df_final[df_final['Series Code'] == 'SP.POP.TOTL']

# %%
sns.lineplot(data=pop_data, x='Year', y='Value', linewidth=2.5, color='blue')
plt.title('Рост населения мира (1990-2024)', fontsize=16)
plt.xlabel('Год', fontsize=12)
plt.ylabel('Население (в миллиардах)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7) # Сетка

# Показываем
plt.show()

# %%
rates_data = df_final[df_final['Series Code'].isin(['SP.DYN.CBRT.IN', 'SP.DYN.CDRT.IN'])]

# %%
sns.lineplot(data=rates_data, x='Year', y='Value', hue='Series Name', linewidth=2.5)
plt.title('Демографический переход: Рождаемость vs Смертность', fontsize=16)
plt.xlabel('Год')
plt.ylabel('Количество на 1000 человек')
plt.grid(True, linestyle='--', alpha=0.5)

# Выносим легенду вбок, чтобы она не перекрывала график
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Показатель')

plt.show()

# %%
if len(pop_data) == 0:
    print("\nДоступные коды в df_final:")
    print(df_final['Series Code'].unique())

# %%
df_final
# Out:
#     Country Name Country Code  \
# 0          World          WLD
# 1          World          WLD
# 2          World          WLD
# 3          World          WLD
# 4          World          WLD
# ..           ...          ...
# 659        World          WLD
# 660        World          WLD
# 662        World          WLD
# 663        World          WLD
# 664        World          WLD
#
#                                            Series Name        Series Code  \
# 0                                    Population, total        SP.POP.TOTL
# 1           Population, female (% of total population)  SP.POP.TOTL.FE.ZS
# 2                 Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 3                 Death rate, crude (per 1,000 people)     SP.DYN.CDRT.IN
# 4             Fertility rate, total (births per woman)     SP.DYN.TFRT.IN
# ..                                                 ...                ...
# 659                                 Labor force, total     SL.TLF.TOTL.IN
# 660  People using at least basic drinking water ser...     SH.H2O.BASW.ZS
# 662  Prevalence of HIV, total (% of population ages...     SH.DYN.AIDS.ZS
# 663  Current health expenditure per capita, PPP (cu...  SH.XPD.CHEX.PP.CD
# 664  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
#
#      Year         Value
# 0    2024  8.142056e+09
# 1    2024  4.972094e+01
# 2    2024  1.633276e+01
# 3    2024  7.578753e+00
# 4    2024  2.195826e+00
# ..    ...           ...
# 659  1990  2.326447e+09
# 660  1990  8.023660e+01
# 662  1990  3.000000e-01
# 663  1990  5.926562e+02
# 664  1990  4.036835e+00
#
# [630 rows x 6 columns]

# %% [markdown]
# Корреляционный анализ

# %%
df_pivot = df_final.pivot(index='Year', columns='Series Name', values='Value')
print(df_pivot.head())
# Out:
# Series Name  Birth rate, crude (per 1,000 people)  \
# Year
# 1990                                    26.258799
# 1991                                    25.637981
# 1992                                    24.956394
# 1993                                    24.564328
# 1994                                    24.191089
#
# Series Name  Current health expenditure per capita, PPP (current international $)  \
# Year
# 1990                                                592.656213
# 1991                                                592.656213
# 1992                                                592.656213
# 1993                                                592.656213
# 1994                                                592.656213
#
# Series Name  Death rate, crude (per 1,000 people)  \
# Year
# 1990                                     9.303795
# 1991                                     9.269572
# 1992                                     9.171566
# 1993                                     9.155776
# 1994                                     9.195078
#
# Series Name  Fertility rate, total (births per woman)  \
# Year
# 1990                                         3.306787
# 1991                                         3.126026
# 1992                                         3.039010
# 1993                                         2.971563
# 1994                                         2.919101
#
# Series Name  GDP per capita, PPP (current international $)  \
# Year
# 1990                                           5581.045562
# 1991                                           5767.150899
# 1992                                           5932.233648
# 1993                                           6090.679062
# 1994                                           6321.078840
#
# Series Name  Government expenditure on education, total (% of GDP)  \
# Year
# 1990                                                  4.036835
# 1991                                                  4.036835
# 1992                                                  4.036835
# 1993                                                  4.036835
# 1994                                                  4.036835
#
# Series Name  Labor force, total  Life expectancy at birth, total (years)  \
# Year
# 1990               2.326447e+09                                65.107983
# 1991               2.367005e+09                                65.303270
# 1992               2.406905e+09                                65.547052
# 1993               2.441983e+09                                65.742050
# 1994               2.484975e+09                                65.957914
#
# Series Name  Mortality rate, infant (per 1,000 live births)  \
# Year
# 1990                                                   64.0
# 1991                                                   64.2
# 1992                                                   63.4
# 1993                                                   62.2
# 1994                                                   61.4
#
# Series Name  People using at least basic drinking water services (% of population)  \
# Year
# 1990                                                 80.236596
# 1991                                                 80.236596
# 1992                                                 80.236596
# 1993                                                 80.236596
# 1994                                                 80.236596
#
# Series Name  Population ages 0-14 (% of total population)  \
# Year
# 1990                                            33.035799
# 1991                                            32.883873
# 1992                                            32.712854
# 1993                                            32.534911
# 1994                                            32.320277
#
# Series Name  Population ages 15-64 (% of total population)  \
# Year
# 1990                                             60.891206
# 1991                                             60.978226
# 1992                                             61.076634
# 1993                                             61.175704
# 1994                                             61.306185
#
# Series Name  Population ages 65 and above (% of total population)  \
# Year
# 1990                                                  6.072995
# 1991                                                  6.137900
# 1992                                                  6.210512
# 1993                                                  6.289386
# 1994                                                  6.373538
#
# Series Name  Population growth (annual %)  \
# Year
# 1990                             1.743506
# 1991                             1.670166
# 1992                             1.631379
# 1993                             1.587706
# 1994                             1.534934
#
# Series Name  Population, female (% of total population)  Population, total  \
# Year
# 1990                                          49.796975       5.299247e+09
# 1991                                          49.782761       5.388496e+09
# 1992                                          49.774235       5.477124e+09
# 1993                                          49.761016       5.564779e+09
# 1994                                          49.755729       5.650853e+09
#
# Series Name  Prevalence of HIV, total (% of population ages 15-49)  \
# Year
# 1990                                                       0.3
# 1991                                                       0.4
# 1992                                                       0.4
# 1993                                                       0.5
# 1994                                                       0.6
#
# Series Name  Urban population (% of total population)
# Year
# 1990                                        42.986512
# 1991                                        43.348159
# 1992                                        43.708801
# 1993                                        44.063901
# 1994                                        44.421845

# %%
plt.figure(figsize=(10, 6))

x_col = 'GDP per capita, PPP (current international $)'
y_col = 'Life expectancy at birth, total (years)'

# Рисуем точечный график
sns.scatterplot(data=df_pivot, x=x_col, y=y_col, s=100, color='crimson', alpha=0.7)

plt.title('Зависимость продолжительности жизни от ВВП', fontsize=14)
plt.xlabel('ВВП на душу населения ($)', fontsize=12)
plt.ylabel('Ожидаемая продолжительность жизни (лет)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
corr_matrix = df_pivot.corr()

# %%
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Тепловая карта корреляции показателей', fontsize=16)
plt.show()

# %%
# Выбираем целевую переменную ВВП
target_col = 'GDP per capita, PPP (current international $)'

# Сортируем связи от самых сильных к самым слабым
gdp_corr = corr_matrix[[target_col]].sort_values(by=target_col, ascending=False)

# Рисуем Heatmap только для одного столбца
plt.figure(figsize=(4, 10)) # Делаем узкую высокую картинку
sns.heatmap(gdp_corr, 
            annot=True,     # Показываем числа на ячейках
            cmap='coolwarm', 
            center=0,
            vmin=-1, vmax=1) # Фиксируем шкалу от -1 до +1

plt.title(f'Что сильнее всего связано с ВВП?', fontsize=14)
plt.show()

# %% [markdown]
# "Корреляция не означает причинно-следственную связь" (Correlation does not imply causation).
# Анализ подтверждает теорию демографического перехода: рост экономического благосостояния (ВВП) имеет сильнейшую обратную связь с рождаемостью и прямую связь с качеством и продолжительностью жизни

# %%
plt.figure(figsize=(10, 5))
# Рисуем просто точки, без линий
sns.scatterplot(data=pop_data, x='Year', y='Value', s=100, color='red')
plt.title('Поиск аномалий визуально')
plt.grid(True)
plt.show()

# %% [markdown]
# Model building

# %%
pop_data = df_final[df_final['Series Code'] == 'SP.POP.TOTL'].copy()
X = pop_data['Year'].values.reshape(-1, 1)
y = pop_data['Value'].values

# %%
simple_model = LinearRegression()
simple_model.fit(X, y)
# Out:
# LinearRegression()

# %%
simple_model.score(X, y)
# Out:
# 0.9997456988189276

# %%
print(f"Коэффициент наклона (w): {simple_model.coef_[0]:.0f}")
print(f"население мира растет на {simple_model.coef_[0]/1e6:.2f} миллионов человек в год (в среднем).")
# Out:
# Коэффициент наклона (w): 84371599
# население мира растет на 84.37 миллионов человек в год (в среднем).

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
poly_model = LinearRegression()
poly_model.fit(X_poly, y)
predictions = poly_model.predict(X_poly)

# %%
future_years = np.arange(2025, 2031).reshape(-1, 1)
future_years_poly = poly.transform(future_years)
future_predictions = poly_model.predict(future_years_poly)

# %%
r2 = r2_score(y, predictions)
r2
# Out:
# 0.9998125891558235

# %%
r2_poly = r2_score(y, predictions)
print(f"Точность Полиномиальной (R2 Score): {r2_poly:.8f}")


X_full = np.concatenate((X, future_years))
X_full_poly = poly.transform(X_full)
y_pred_full = poly_model.predict(X_full_poly)
# Out:
# Точность Полиномиальной (R2 Score): 0.99981259

# %%
plt.figure(figsize=(12, 6))

# Точки (история)
plt.scatter(X, y, color='black', label='Реальные факты')

# Линия регрессии (прогноз и история)
plt.plot(X_full, y_pred_full, color='red', linewidth=3, label=f'Полиномиальная регрессия (R2={r2_poly:.8f})')

plt.title('Прогноз населения: Полиномиальная модель vs История', fontsize=16)
plt.xlabel('Год')
plt.ylabel('Население')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"🔮 Прогноз на 2030 год: {future_predictions[-1] / 1e9:.2f} млрд человек")
# Out:
# 🔮 Прогноз на 2030 год: 8.66 млрд человек

# %%
year_2030 = np.array([[2030]])
year_2030_poly = poly.transform(year_2030)


pred_linear = simple_model.predict(year_2030)[0]
pred_poly = poly_model.predict(year_2030_poly)[0]

# 3. Считаем разницу
diff = abs(pred_linear - pred_poly)

print(f"🔮 Прогноз на 2030 год:")
print(f"➖ Линейная (Прямая):  {pred_linear / 1e9:.3f} млрд")
print(f"➰ Полиномиальная:     {pred_poly / 1e9:.3f} млрд")
print(f"🤯 Разница:            {diff / 1e6:.1f} МИЛЛИОНОВ человек!")
# Out:
# 🔮 Прогноз на 2030 год:
# ➖ Линейная (Прямая):  8.689 млрд
# ➰ Полиномиальная:     8.657 млрд
# 🤯 Разница:            32.7 МИЛЛИОНОВ человек!

# %%
pop_data['Predicted_Value'] = poly_model.predict(X_poly) 

# 2. Создаем DataFrame только для прогноза (2025-2030)
future_df = pd.DataFrame({
    'Year': future_years.flatten(),
    'Value': future_predictions.flatten(),
    'Series Code': 'SP.POP.TOTL_PROJ', 
    'Series Name': 'Total Population Projection',
    'Country Code': 'WLD',
    'Country Name': 'World'
})

# 3. Объединяем историю и прогноз
df_history = df_final[df_final['Series Code'] == 'SP.POP.TOTL'].copy()
df_final_for_tableau = pd.concat([df_history[['Year', 'Value', 'Series Code', 'Country Name']], 
                                   future_df[['Year', 'Value', 'Series Code', 'Country Name']]], 
                                  ignore_index=True)

# %%
df_final_for_tableau.to_csv('global_demographics_final.csv', index=False)

print(" Файл 'global_demographics_final.csv' сохранен.")
# Out:
#  Файл 'global_demographics_final.csv' сохранен.
